# %%
from qiskit import QuantumCircuit, execute
import matplotlib.pyplot as plt
from qiskit.test.mock import FakeManhattan, FakeBoeblingen, FakeQuito
from qiskit.transpiler import CouplingMap
from qiskit.visualization import plot_gate_map, plot_circuit_layout, plot_histogram
# Out:
# /Applications/anaconda3/envs/qiskit-terra-dev/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from qiskit.transpiler.passes.layout import CSPWCRLayout
# Out:
# /Applications/anaconda3/envs/qiskit-terra-dev/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from exp.circuit_generators import graphstate_complete

# %%
def run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs):
    backend_config = backend.configuration()
    coupling_map = CouplingMap(backend_config.coupling_map)
    pass_ = layout_selector(CouplingMap(backend.configuration().coupling_map), **kwargs)
    property_set = {}
    pass_(circuit, property_set)
    circuit._layout = property_set['layout']
    return circuit

def layout_on_circuit(circuit, layout_selector, backend, **kwargs):
    circuit = run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs)
    return plot_circuit_layout(circuit, backend)

# %%
circuit = graphstate_complete(12)
backend = FakeManhattan()

# %%
plot_gate_map(backend)

# %%
layout_on_circuit(circuit, CSPWCRLayout, backend, seed=42, relaxation_limit=66)

# %%
backend = FakeBoeblingen()
print(backend.configuration().coupling_map)
# Out:
# [[0, 1], [1, 0], [1, 2], [1, 6], [2, 1], [2, 3], [3, 2], [3, 4], [3, 8], [4, 3], [5, 6], [5, 10], [6, 1], [6, 5], [6, 7], [7, 6], [7, 8], [7, 12], [8, 3], [8, 7], [8, 9], [9, 8], [9, 14], [10, 5], [10, 11], [11, 10], [11, 12], [11, 16], [12, 7], [12, 11], [12, 13], [13, 12], [13, 14], [13, 18], [14, 9], [14, 13], [15, 16], [16, 11], [16, 15], [16, 17], [17, 16], [17, 18], [18, 13], [18, 17], [18, 19], [19, 18]]

# %%
plot_gate_map(backend)

# %%
circuit = graphstate_complete(6)
layout_on_circuit(circuit, CSPWCRLayout, backend, seed=43, relaxation_limit=66)
# Out:
#  0
# node2:  1
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 6}), (1, 4, {'weight': 4}), (1, 2, {'weight': 4}), (2, 5, {'weight': 2}), (3, 4, {'weight': 2})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 6}), (1, 4, {'weight': 4}), (1, 2, {'weight': 4}), (2, 5, {'weight': 2}), (3, 4, {'weight': 2})]
# node1:  1
# node2:  2
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 2}), (2, 3, {'weight': 4}), (3, 4, {'weight': 2})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 2}), (2, 3, {'weight': 4}), (3, 4, {'weight': 2})]
# node1:  2
# node2:  3
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 2}), (3, 5, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 2}), (3, 5, {'weight': 4})]
# node1:  3
# node2:  5
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3}), (4, 5, {'weight': 4})]
# node1:  4
# node2:  5
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 5}), (1, 5, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 7}), (1, 4, {'weight': 5}), (1, 5, {'weight': 4}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3})]
# node1:  1
# node2:  5
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3}), (3, 5, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 3}), (3, 5, {'weight': 4})]
# node1:  3
# node2:  5
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 5}), (0, 4, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 5}), (0, 4, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4})]
# node1:  0
# node2:  4
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 6}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 6}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 3}), (3, 4, {'weight': 4}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 6}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 4})]
# [(0, 2, {'weight': 4}), (0, 5, {'weight': 6}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 4})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 4, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 4})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 4, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 4})]
# node1:  4
# node2:  0
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 3, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 3, {'weight': 4}), (1, 3, {'weight': 8}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  3
# node2:  0
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 1, {'weight': 4}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 6}), (0, 1, {'weight': 4}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  0
# node2:  1
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 7}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (1, 5, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 7}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (1, 5, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  5
# node2:  1
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 9}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  1
# node2:  0
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 10}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 10}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  3
# node2:  0
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 5}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  0
# node2:  1
# [(0, 2, {'weight': 6}), (0, 5, {'weight': 8}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 6}), (0, 5, {'weight': 8}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  2
# node2:  1
# [(0, 2, {'weight': 7}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 7}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  0
# node2:  1
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 11}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  1
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 3, {'weight': 4}), (3, 4, {'weight': 5})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 3, {'weight': 4}), (3, 4, {'weight': 5})]
# node1:  3
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 6})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 6})]
# node1:  4
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 12}), (1, 4, {'weight': 5}), (2, 5, {'weight': 4}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  3
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 5}), (1, 2, {'weight': 4}), (2, 5, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  1
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 4}), (2, 4, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 5}), (3, 4, {'weight': 7}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 5}), (3, 4, {'weight': 7}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 6}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  4
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 7}), (1, 2, {'weight': 4}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 13}), (1, 4, {'weight': 7}), (1, 2, {'weight': 4}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# node1:  1
# node2:  2
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 14}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 8}), (0, 5, {'weight': 8}), (1, 3, {'weight': 14}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  2
# node2:  3
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 14}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 14}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# node1:  3
# node2:  0
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 15}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 1, {'weight': 4}), (1, 3, {'weight': 15}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# node1:  1
# node2:  0
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 9}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# node1:  0
# node2:  3
# [(0, 2, {'weight': 10}), (0, 5, {'weight': 8}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 10}), (0, 5, {'weight': 8}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 3, {'weight': 4}), (3, 4, {'weight': 7})]
# node1:  2
# node2:  3
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 8}), (0, 3, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7})]
# node1:  0
# node2:  3
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 9}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7}), (3, 5, {'weight': 4})]
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 9}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 7}), (3, 5, {'weight': 4})]
# node1:  3
# node2:  5
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 9}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 9}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 10}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 11}), (0, 5, {'weight': 10}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# node1:  0
# node2:  4
# [(0, 2, {'weight': 12}), (0, 5, {'weight': 10}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 12}), (0, 5, {'weight': 10}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 8})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 10}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 10}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 7}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# node1:  4
# node2:  0
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 10}), (0, 1, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 8}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 10}), (0, 1, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 8}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# node1:  0
# node2:  1
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 11}), (1, 3, {'weight': 16}), (1, 4, {'weight': 8}), (1, 5, {'weight': 4}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 11}), (1, 3, {'weight': 16}), (1, 4, {'weight': 8}), (1, 5, {'weight': 4}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# node1:  1
# node2:  5
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 11}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 11}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 12}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 13}), (0, 5, {'weight': 12}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (3, 4, {'weight': 8})]
# node1:  0
# node2:  4
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 12}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 12}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 6}), (2, 4, {'weight': 4}), (3, 4, {'weight': 8})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 12}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 12}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8}), (4, 5, {'weight': 4})]
# node1:  5
# node2:  4
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 9}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# node1:  4
# node2:  0
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 1, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 1, {'weight': 4}), (1, 3, {'weight': 16}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# node1:  1
# node2:  0
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 3, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 14}), (0, 5, {'weight': 13}), (0, 3, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 8})]
# node1:  0
# node2:  3
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 8})]
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 8})]
# node1:  3
# node2:  2
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 9})]
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 9})]
# node1:  4
# node2:  2
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 10})]
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 10})]
# node1:  3
# node2:  2
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# [(0, 2, {'weight': 15}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 16}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 11})]
# [(0, 2, {'weight': 16}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 11})]
# node1:  0
# node2:  4
# [(0, 2, {'weight': 17}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# [(0, 2, {'weight': 17}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# node1:  2
# node2:  4
# [(0, 2, {'weight': 18}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 11})]
# [(0, 2, {'weight': 18}), (0, 5, {'weight': 13}), (0, 4, {'weight': 4}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (3, 4, {'weight': 11})]
# node1:  0
# node2:  4
# [(0, 2, {'weight': 19}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# [(0, 2, {'weight': 19}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 11})]
# node1:  4
# node2:  2
# [(0, 2, {'weight': 19}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 12})]
# [(0, 2, {'weight': 19}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 3, {'weight': 4}), (3, 4, {'weight': 12})]
# node1:  3
# node2:  2
# [(0, 2, {'weight': 19}), (0, 5, {'weight': 13}), (1, 3, {'weight': 17}), (1, 4, {'weight': 10}), (2, 5, {'weight': 7}), (2, 4, {'weight': 4}), (3, 4, {'weight': 13})]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-cf4f6e0c0388> in <module>
#       1 circuit = graphstate_complete(6)
# ----> 2 layout_on_circuit(circuit, CSPWCRLayout, backend, seed=43, relaxation_limit=66)
#
# <ipython-input-4-3f7c19a8e852> in layout_on_circuit(circuit, layout_selector, backend, **kwargs)
#       9
#      10 def layout_on_circuit(circuit, layout_selector, backend, **kwargs):
# ---> 11     circuit = run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs)
#      12     return plot_circuit_layout(circuit, backend)
#
# <ipython-input-4-3f7c19a8e852> in run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs)
#       5     property_set = {}
#       6     pass_(circuit, property_set)
# ----> 7     circuit._layout = property_set['layout']
#       8     return circuit
#       9
#
# KeyError: 'layout'

# %%
backend = FakeQuito()
print(backend.configuration().coupling_map)
# Out:
# [[0, 1], [1, 0], [1, 2], [1, 3], [2, 1], [3, 1], [3, 4], [4, 3]]

# %%
plot_gate_map(backend)

# %%
circuit = graphstate_complete(5)
layout_on_circuit(circuit, CSPWCRLayout, backend, seed=43, relaxation_limit=66)
# Out:
# [(0, 1, {'weight': 1}), (0, 2, {'weight': 1}), (0, 3, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 1}), (1, 3, {'weight': 1}), (1, 4, {'weight': 1}), (2, 3, {'weight': 1}), (2, 4, {'weight': 1}), (3, 4, {'weight': 1})]
# node1:  0
# node2:  3
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 1}), (1, 3, {'weight': 2}), (1, 4, {'weight': 1}), (2, 3, {'weight': 1}), (2, 4, {'weight': 1}), (3, 4, {'weight': 1})]
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 1}), (1, 3, {'weight': 2}), (1, 4, {'weight': 1}), (2, 3, {'weight': 1}), (2, 4, {'weight': 1}), (3, 4, {'weight': 1})]
# node1:  4
# node2:  1
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 3, {'weight': 1}), (2, 4, {'weight': 2}), (3, 4, {'weight': 1})]
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 3, {'weight': 1}), (2, 4, {'weight': 2}), (3, 4, {'weight': 1})]
# node1:  2
# node2:  3
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 4, {'weight': 3}), (3, 4, {'weight': 2})]
# [(0, 1, {'weight': 2}), (0, 2, {'weight': 1}), (0, 4, {'weight': 1}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 4, {'weight': 3}), (3, 4, {'weight': 2})]
# node1:  0
# node2:  2
# [(0, 1, {'weight': 2}), (0, 4, {'weight': 2}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 4, {'weight': 4}), (3, 4, {'weight': 2})]
# [(0, 1, {'weight': 2}), (0, 4, {'weight': 2}), (1, 2, {'weight': 2}), (1, 3, {'weight': 2}), (2, 4, {'weight': 4}), (3, 4, {'weight': 2})]
# node1:  4
# node2:  3
# [(0, 1, {'weight': 3}), (0, 4, {'weight': 4}), (1, 2, {'weight': 2}), (1, 3, {'weight': 3}), (2, 4, {'weight': 4})]
# [(0, 1, {'weight': 3}), (0, 4, {'weight': 4}), (1, 2, {'weight': 2}), (1, 3, {'weight': 3}), (2, 4, {'weight': 4})]
# node1:  1
# node2:  2
# [(0, 1, {'weight': 5}), (0, 4, {'weight': 5}), (1, 3, {'weight': 3}), (2, 4, {'weight': 5})]
# [(0, 1, {'weight': 5}), (0, 4, {'weight': 5}), (1, 3, {'weight': 3}), (2, 4, {'weight': 5})]
# node1:  4
# node2:  0
# [(0, 1, {'weight': 5}), (0, 2, {'weight': 5}), (1, 3, {'weight': 3}), (2, 4, {'weight': 6})]
# [(0, 1, {'weight': 5}), (0, 2, {'weight': 5}), (1, 3, {'weight': 3}), (2, 4, {'weight': 6})]
# node1:  1
# node2:  0
# [(0, 2, {'weight': 5}), (0, 3, {'weight': 5}), (1, 3, {'weight': 4}), (2, 4, {'weight': 6})]
# [(0, 2, {'weight': 5}), (0, 3, {'weight': 5}), (1, 3, {'weight': 4}), (2, 4, {'weight': 6})]
# node1:  0
# node2:  2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-bae30605364e> in <module>
#       1 circuit = graphstate_complete(5)
# ----> 2 layout_on_circuit(circuit, CSPWCRLayout, backend, seed=43, relaxation_limit=66)
#
# <ipython-input-4-3f7c19a8e852> in layout_on_circuit(circuit, layout_selector, backend, **kwargs)
#       9
#      10 def layout_on_circuit(circuit, layout_selector, backend, **kwargs):
# ---> 11     circuit = run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs)
#      12     return plot_circuit_layout(circuit, backend)
#
# <ipython-input-4-3f7c19a8e852> in run_layout_selector_on_circuit(circuit, layout_selector, backend, **kwargs)
#       4     pass_ = layout_selector(CouplingMap(backend.configuration().coupling_map), **kwargs)
#       5     property_set = {}
# ----> 6     pass_(circuit, property_set)
#       7     circuit._layout = property_set['layout']
#       8     return circuit
#
# ~/Workbench/qiskit-terra/qiskit/transpiler/basepasses.py in __call__(self, circuit, property_set)
#     119             self.property_set = property_set_
#     120
# --> 121         result = self.run(circuit_to_dag(circuit))
#     122
#     123         result_circuit = circuit
#
# ~/Workbench/qiskit-terra/qiskit/transpiler/passes/layout/cspwcr_layout.py in run(self, dag)
#     198
#     199             if not self._check_degree_lcm(lcm, pcm):
# --> 200                 self._mod_lcm(lcm)
#     201             else:
#     202                 solver = CustomSolver(call_limit=self.call_limit,
#
# ~/Workbench/qiskit-terra/qiskit/transpiler/passes/layout/cspwcr_layout.py in _mod_lcm(self, lcm)
#     318             Input:
#     319                 lcm:
# --> 320                 pcm:
#     321             Output:
#     322                 mappable (Bool): Is lcm mappable to pcm
#
# /Applications/anaconda3/envs/qiskit-terra-dev/lib/python3.8/random.py in choice(self, seq)
#     288             i = self._randbelow(len(seq))
#     289         except ValueError:
# --> 290             raise IndexError('Cannot choose from an empty sequence') from None
#     291         return seq[i]
#     292
#
# IndexError: Cannot choose from an empty sequence
